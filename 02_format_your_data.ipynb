# %% [markdown]
# # 02 Format your data for modeling
#
# This notebook shows five quick formatting steps that turn a small email dataset into numeric features ready for scikit-learn.

# %% [markdown]
# ## Create a sample email dataset

# %%
import pandas as pd
import numpy as np
import sklearn

data = {
    "subject": [
        "Win a free vacation",
        "Your receipt from Bookstore",
        "Limited time offer",
        "Meeting agenda",
        "Update your account info",
        "Family photos inside",
        "Exclusive promo just for you",
        "Weekly project status"
    ],
    "label": [
        "spam",
        "not_spam",
        "spam",
        "not_spam",
        "spam",
        "not_spam",
        "spam",
        "not_spam"
    ],
    "sender_domain": [
        "promos.biz",
        "gmail.com",
        "offers.mail",
        "company.com",
        "alerts.bank",
        "yahoo.com",
        "promos.biz",
        "company.com"
    ],
    "num_links": [5, 0, 7, 1, np.nan, 0, 4, 1],
    "num_words": [40, 120, 35, 80, 60, 100, 50, 90],
    "received_date": [
        "2024-01-15",
        "2024-01-18",
        "2024-02-02",
        "2024-02-10",
        "2024-03-05",
        "2024-03-08",
        "2024-03-20",
        "2024-04-01"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                         subject     label sender_domain  num_links  num_words  \
# 0           Win a free vacation      spam    promos.biz        5.0         40
# 1   Your receipt from Bookstore  not_spam     gmail.com        0.0        120
# 2            Limited time offer      spam   offers.mail        7.0         35
# 3                Meeting agenda  not_spam   company.com        1.0         80
# 4      Update your account info      spam   alerts.bank        NaN         60
# 5          Family photos inside  not_spam     yahoo.com        0.0        100
# 6  Exclusive promo just for you      spam    promos.biz        4.0         50
# 7         Weekly project status  not_spam   company.com        1.0         90
#
#   received_date
# 0    2024-01-15
# 1    2024-01-18
# 2    2024-02-02
# 3    2024-02-10
# 4    2024-03-05
# 5    2024-03-08
# 6    2024-03-20
# 7    2024-04-01

# %% [markdown]
# ## 1. Convert string labels to numeric

# %% [markdown]
# ## 2. Create dummy variables for sender_domain

# %% [markdown]
# ## 3. Handle missing numeric values

# %% [markdown]
# ## 4. Standard scale numeric features

# %% [markdown]
# to see whether how the data deviate from the median
# - if +, more than median
# - if -, less tham median

# %%
scaler = sklearn.preprocessing.StandardScaler()
df["num_links_original"] = df["num_links"]
df["num_words_original"] = df["num_words"]
df[["num_links", "num_words"]] = scaler.fit_transform(df[["num_links", "num_words"]])
df[["num_links_original", "num_links", "num_words_original", "num_words"]]
# Out:
#    num_links_original  num_links  num_words_original  num_words
# 0                 5.0   0.950329                  40  -1.118518
# 1                 0.0  -1.006231                 120   1.688743
# 2                 7.0   1.732953                  35  -1.293972
# 3                 1.0  -0.614919                  80   0.285112
# 4                 NaN        NaN                  60  -0.416703
# 5                 0.0  -1.006231                 100   0.986928
# 6                 4.0   0.559017                  50  -0.767610
# 7                 1.0  -0.614919                  90   0.636020

# %% [markdown]
# ## 5. Extract month from received_date

# %%
df.dtypes
# Out:
# subject                object
# label                  object
# sender_domain          object
# num_links             float64
# num_words             float64
# received_date          object
# num_links_original    float64
# num_words_original      int64
# dtype: object

# %%
df["received_month"] = pd.to_datetime(df["received_date"]).dt.month
df["received_date"] = pd.to_datetime(df["received_date"]).dt.date
df[["received_date", "received_month"]]
# Out:
#   received_date  received_month
# 0    2024-01-15               1
# 1    2024-01-18               1
# 2    2024-02-02               2
# 3    2024-02-10               2
# 4    2024-03-05               3
# 5    2024-03-08               3
# 6    2024-03-20               3
# 7    2024-04-01               4

# %% [markdown]
# ## Final formatted DataFrame

# %%
df
# Out:
#                         subject     label sender_domain  num_links  num_words  \
# 0           Win a free vacation      spam    promos.biz   0.950329  -1.118518
# 1   Your receipt from Bookstore  not_spam     gmail.com  -1.006231   1.688743
# 2            Limited time offer      spam   offers.mail   1.732953  -1.293972
# 3                Meeting agenda  not_spam   company.com  -0.614919   0.285112
# 4      Update your account info      spam   alerts.bank        NaN  -0.416703
# 5          Family photos inside  not_spam     yahoo.com  -1.006231   0.986928
# 6  Exclusive promo just for you      spam    promos.biz   0.559017  -0.767610
# 7         Weekly project status  not_spam   company.com  -0.614919   0.636020
#
#   received_date  num_links_original  num_words_original  received_month
# 0    2024-01-15                 5.0                  40               1
# 1    2024-01-18                 0.0                 120               1
# 2    2024-02-02                 7.0                  35               2
# 3    2024-02-10                 1.0                  80               2
# 4    2024-03-05                 NaN                  60               3
# 5    2024-03-08                 0.0                 100               3
# 6    2024-03-20                 4.0                  50               3
# 7    2024-04-01                 1.0                  90               4
